# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
 
# create data
x = np.random.rand(15)
y = x+np.random.rand(15)
z = x+np.random.rand(15)
z=z*z
colors = ('red', 'blue', 'green')
label="Urban"

# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, y, s=z*2000, c=colors, cmap="Reds", alpha=.75, edgecolors="grey", linewidth=2)
 
# Add titles (main and on axis)
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data")
plt.legend(loc="best")
 
plt.show()

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
 
# create data
x = np.random.rand(15)
y = x+np.random.rand(15)
z = x+np.random.rand(15)
z=z*z
colors = ("gold","lightskyblue","lightcoral")
labelType= ('Rural','Urban','Subburban')

# Change color with c and alpha. I map the color to the X axis value.
#plt.scatter(x, y, s=z*2000, c=colors, cmap="Reds", alpha=.75, edgecolors="grey", linewidth=2)
 

fig, ax = plt.subplots()
for color in [labelType]:
    n = 750
    x, y = rand(2, n)
    scale = 200.0 * rand(n)
    ax.scatter(x, y, c=colors, s=scale, alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(True)

plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data")
plt.legend(loc="best")
plt.legend(['Rural', 'Urban', 'Subburban'])
plt.show()

# %%
from numpy.random import randn

z = randn(10)

red_dot, = plt.plot(z, "ro", markersize=15)
# Put a white cross over some of the data.
white_cross, = plt.plot(z[:5], "w+", markeredgewidth=3, markersize=15)

plt.legend([red_dot, (red_dot, white_cross)], ["Attr A", "Attr A+B"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Ellipse

NUM = 250

ells = [Ellipse(xy=np.random.rand(2) * 10,
                width=np.random.rand(), height=np.random.rand(),
                angle=np.random.rand() * 360)
        for i in range(NUM)]

fig, ax = plt.subplots(subplot_kw={'aspect': 'equal'})
for e in ells:
    ax.add_artist(e)
    e.set_clip_box(ax.bbox)
    e.set_alpha(np.random.rand())
    e.set_facecolor(np.random.rand(3))

ax.set_xlim(0, 10)
ax.set_ylim(0, 10)

plt.show()

# %%
line1, = plt.plot([1, 2, 3], label="Line 1", linestyle='--')
line2, = plt.plot([3, 2, 1], label="Line 2", linewidth=4)

# Create a legend for the first line.
first_legend = plt.legend(handles=[line1], loc=1)

# Add the legend manually to the current Axes.
ax = plt.gca().add_artist(first_legend)

# Create another legend for the second line.
plt.legend(handles=[line2], loc=4)

plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.random import rand

labelType= ['Rural','Urban','Subburban']
fig, ax = plt.subplots()
x=0
color= ["gold","lightskyblue","lightcoral"]
#     n = 750
x, y = rand(2, n)
#     scale = 200.0 * rand(n)
#     ax.scatter(x, y, c=color, s=scale, label=labelType[x],
#                alpha=0.3, edgecolors='none')
plt.scatter(x, y, c="gold", s=3, label="Rural",
               alpha=0.3, edgecolors='none')
plt.scatter(x, y, c='blue', s=3, label="Urban",
               alpha=0.3, edgecolors='none')
plt.scatter(x, y, c='red', s=3, label="Subburban",
               alpha=0.3, edgecolors='none')
    
#ax.scatter.label=labelType[color]
plt.legend()
plt.grid(True)
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data")
#plt.legend(loc="best")


plt.show()

# %%
colors = ("gold","lightskyblue","lightcoral")

# %%
colors
# Out:
# ('gold', 'lightskyblue', 'lightcoral')

# %%
colors[0]
# Out:
# 'gold'

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1,1,100)

fig = plt.figure()
ax = fig.add_subplot(1,1,1)

#Plot something
ax.plot(x,x, color='red', ls="-", label="Rural")
ax.plot(x,0.5 * (3*x**2-1), color='green', ls="--", label="$P_2(x)$")
ax.plot(x,0.5 * (5*x**3-3*x), color='blue', ls=":", label="$P_3(x)$")

ax.legend()
plt.show()

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch = mpatches.Patch(color='red', label='The red data')
blue_patch = mpatches.Patch(color='blue', label='The blue data')
gold_patch = mpatches.Patch(color='gold', label='Urban')

plt.legend([red_patch, blue_patch, gold_patch], ['Line Up', 'Line Down','Urban'])
plt.show()
